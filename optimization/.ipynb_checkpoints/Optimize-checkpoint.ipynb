# %%
def optimize(file):
    optimized=[]
    lines=[]
    table={}
    which_is_which={}
    def what_is(a):
        while(1):
            b=which_is_which[a]
            if(b==None):
                break
            a=b
        return a
    with open(file) as f:
        c=f.readline()
        while(c):
            lines.append((c.split('\n')[0]).strip())
            c=f.readline()
    f=lines
    for i  in lines:
        print(i)
    print('\n\n\n\n\n\n')
    for ln in lines:
        line=(ln.split('\n')[0]).strip()
        #print(line)
        if("=" in line):
            #print(table)
            lst = [x.strip() for x in line.split(" = ")]
            lst1 = lst[1].split(" ")
            
            #a = 1
            if(lst1[0].isnumeric() and len(lst1) == 1 and (lst[0].isalpha())):
                table[lst[0]] = int(lst1[0])
                print(lst[0], "=", table[lst[0]])
                optimized.append(lst[0]+ " = "+str(table[lst[0]]))
                which_is_which[lst[0]]=None
                #print(table)

            #i = t1
            elif(len(lst1) == 1 and ((lst[0] not in table) and (lst[0].isalpha()) and (not lst1[0].isnumeric()) and (lst1[0] in table) )):
                #print("I=T1",lst1[0],lst[0])
                table[lst[0]] = table[lst1[0]]
                which_is_which[lst[0]]=lst1[0]
                print(lst[0], "=", table[lst[0]])
                optimized.append(lst[0]+ " = "+str(table[lst[0]]))
                #del table[lst1[0]]

            #t2 = t1 
            elif(len(lst1) == 1 and (not lst1[0].isnumeric()) and (lst1[0] in table) and (not lst[0].isnumeric()) and (lst[0] not in table) ):
                #print("T2=T1",lst1[0],lst[0])
                table[lst[0]] = table[lst1[0]]
                which_is_which[lst[0]]=lst1[0]
                #del table[lst1[0]]
                #print(table)
            # t1 = a + 5
            elif(lst1[0].isalpha and len(lst1) > 1 and lst1[0] in table and lst1[2].isnumeric() ):
                value = table[lst1[0]]
                lst[1] = str(value) + " " + lst1[1] + " " + lst1[2]
                table[lst[0]] = eval(lst[1])
                print(lst[0] ,"=", table[lst[0]])
                optimized.append(lst[0]+ " = "+str(table[lst[0]]))
                which_is_which[lst[0]]=None
                #print(table)

            # t1 = 5 + a
            elif(len(lst1) > 1 and lst1[2].isalpha and lst1[2] in table and lst1[0].isnumeric()):
                value = table[lst1[2]]
                lst[1] = lst1[0] + lst1[1] + str(value)
                table[lst[0]] = eval(lst[1])
                print(lst[0] ,"=", table[lst[0]])
                optimized.append(lst[0]+ " = "+str(table[lst[0]]))
                which_is_which[lst[0]]=None
                #print(table)

            #t1 = 2 + 2
            elif(lst1[0].isnumeric() and lst1[2].isnumeric()):
                table[lst[0]] = eval(lst[1])
                print(lst[0] ,"=", table[lst[0]])
                optimized.append(lst[0]+ " = "+str(table[lst[0]]))
                which_is_which[lst[0]]=None
                #print(table)        

            #t3 = t1 + t2
            elif((not lst1[0].isnumeric()) and len(lst1) > 1 and (not (lst1[2].isnumeric())) and (lst1[0] in table) and (lst1[2] in table)):
                value1 = table[lst1[0]]
                value2 = table[lst1[2]]
                if("<" in lst1[1] or ">" in lst1[1] or "<=" in lst1[1] or ">=" in lst1[1] or "==" in lst1[1]):
                    lst[1] = str(value1) + " " + lst1[1] + " " + str(value2)
                    table[lst[0]] = eval(lst[1])
                    print(lst[0] ,"=", table[lst[0]])
                    optimized.append(lst[0]+ " = "+str(table[lst[0]]))
                else:
                    lst[1] = str(value1) + " " + lst1[1] + " " + str(value2)
                    table[lst[0]] = eval(lst[1])
                    print(lst[0] ,"=", table[lst[0]])
                    optimized.append(lst[0]+ " = "+str(table[lst[0]]))
                which_is_which[lst[0]]=None
                #print(table)

            # t5 = t1 + 5
            elif((not lst1[0].isnumeric()) and len(lst1) > 1 and (lst1[2].isnumeric()) and (lst1[0] in table)):
                value = table[lst1[0]]
                if("<" in lst1[1] or ">" in lst1[1] or "<=" in lst1[1] or ">=" in lst1[1] or "==" in lst1[1]):
                    lst[1] = str(value) + " " + lst1[1] + " " + lst1[2]
                    table[lst[0]] = eval(lst[1])
                    print(lst[0] ,"=", table[lst[0]])
                    optimized.append(lst[0]+ " = "+str(table[lst[0]]))
                else:
                    lst[1] = str(value) + " " + lst1[1] + " " + lst1[2]
                    table[lst[0]] = eval(lst[1])
                    print(lst[0] ,"=", table[lst[0]])
                    optimized.append(lst[0]+ " = "+str(table[lst[0]]))
                which_is_which[lst[0]]=None
                #print(table)

            # t5 = 5 + t1
            elif(len(lst1) > 1 and (not lst1[2].isnumeric()) and (lst1[0].isnumeric()) and (lst1[2] in table)):
                value = table[lst1[2]]
                if("<" in lst1[1] or ">" in lst1[1] or "<=" in lst1[1] or ">=" in lst1[1] or "==" in lst1[1]):
                    lst[1] = lst1[0] + lst1[1] + str(value)
                    table[lst[0]] = eval(lst[1])
                    print(lst[0] ,"=", table[lst[0]])
                    optimized.append(lst[0]+ " = "+str(table[lst[0]]))
                else:
                    lst[1] = lst1[0] + lst1[1] + str(value)
                    table[lst[0]] = eval(lst[1])
                    print(lst[0] ,"=", table[lst[0]])
                    optimized.append(lst[0]+ " = "+str(table[lst[0]]))
                which_is_which[lst[0]]=None
                #print(table)
            else:
                print(line)
                optimized.append(line)

        elif("if" in line):
            lst = line.split(" ")
            if(lst[1] in table.keys()):
                value = table[lst[1]]
                output = str(lst[0]) + " " + str(value) + " " + " ".join(lst[2:])
                print(output)
                optimized.append(output)
            else:
                print(line)
                optimized.append(line)
        elif("print" in line):
            lst = line.split(" ")
            if(lst[1] in which_is_which.keys()):
                output = "print " + str(table[lst[1]])
                print(output)
                optimized.append(output)
            else:
                print(line)
                optimized.append(line)
        elif("goto" in line.split(" ")[0]):
            print(line)
            optimized.append(line)
        elif("L" in line.split(" ")[0]):
            print(line)
            optimized.append(line)
        elif("main" in line.split(" ")[0]):
            print(line)
            optimized.append(line)
        elif("BEGIN" in line.split(" ")[0]):
            print(line)
            optimized.append(line)
        elif("END" in line.split(" ")[0]):
            print(line)
            optimized.append(line)
        elif("next" in line.split(" ")[0]):
            print(line)
            optimized.append(line)
        else:
            print(line)
            optimized.append(line)
    with open('../IO/optimized.icg','w') as of:
        for i in optimized:
            of.write(i+'\n')
        
    #print(which_is_which)
    #print(table)

# %%
optimize("../IO/icg.icg")
# Out:
# main:
# int a
# a = 10
# int b
# b = 0
# BEGIN1 :
# t1 = a > 0
# ifFalse t1 goto END1
# L1 :
# t2 = a - 1
# a = t2
# t3 = a == 5
# ifFalse t3 goto L3
# b = 1
# L3:
# goto BEGIN1
# END1 :
# return 0
# next :
#
#
#
#
#
#
#
# main:
# int a
# a = 10
# int b
# b = 0
# BEGIN1 :
# t1 = True
# ifFalse True goto END1
# L1 :
# t2 = 9
# a = t2
# t3 = False
# ifFalse False goto L3
# b = 1
# L3:
# goto BEGIN1
# END1 :
# return 0
# next :

# %%
optimize('tests/ip.icg')
# Out:
# a = 10
# b = 9
# t0 = a + b
# t1 = t0
# e = t1 + 4
# f = e + 7
# t1 = 1 + f
# print t1
#
#
#
#
#
#
#
# a = 10
# b = 9
# t0 = 19
# e = 23
# f = 30
# t1 = 31
# print 31

# %%
optimize('tests/ip2.icg')
# Out:
# a = 10
# b = a
# c = 100 + a
# t0 = b
# a = c
# b = 11
# print b
# print t0
#
#
#
#
#
#
#
# a = 10
# b = 10
# c = 110
# a = c
# b = 11
# print 11
# print 10

# %%
optimize('tests/ip3.icg')
# Out:
# a = 10
# b = a
# c = b
# d = c - 10
# t0 = b + 10
# a = c
# b = 11
# int f
# t0 = c * 9
# t1 = f * 20
# print b
# print t0
#
#
#
#
#
#
#
# a = 10
# b = 10
# c = 10
# d = 0
# t0 = 20
# a = c
# b = 11
# int f
# t0 = 90
# t1 = f * 20
# print 11
# print 90
